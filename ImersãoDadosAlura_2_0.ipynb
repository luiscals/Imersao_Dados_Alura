# %%
import pandas as pd


#Selecionando a fonte de dados

fonte = 'https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true'

dados = pd.read_csv(fonte)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
#vendo o tamanho do dataset (retorno = (linhas, colunas))
dados.shape
# Out:
# (127380, 136)

# %%
#vendo od dados únicos de uma coluna
dados["SG_UF_RESIDENCIA"].unique()
# Out:
# array(['PA', 'RO', 'MT', 'AC', 'AM', 'RR', 'MA', 'PR', 'BA', 'PI', 'CE',
#        'PE', 'AP', 'TO', 'SC', 'GO', 'MG', 'SP', 'SE', 'RJ', 'PB', 'AL',
#        'RN', 'ES', 'DF', 'RS', 'MS'], dtype=object)

# %%
dados.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
dados[["SG_UF_RESIDENCIA","Q025"]]
# Out:
#        SG_UF_RESIDENCIA Q025
# 0                    PA    B
# 1                    PA    B
# 2                    PA    B
# 3                    PA    B
# 4                    PA    B
# ...                 ...  ...
# 127375               MG    B
# 127376               BA    B
# 127377               BA    B
# 127378               BA    A
# 127379               MG    B
#
# [127380 rows x 2 columns]

# %%
dados["SG_UF_RESIDENCIA"]
# Out:
# 0         PA
# 1         PA
# 2         PA
# 3         PA
# 4         PA
#           ..
# 127375    MG
# 127376    BA
# 127377    BA
# 127378    BA
# 127379    MG
# Name: SG_UF_RESIDENCIA, Length: 127380, dtype: object

# %%
dados["SG_UF_RESIDENCIA"].unique()
# Out:
# array(['PA', 'RO', 'MT', 'AC', 'AM', 'RR', 'MA', 'PR', 'BA', 'PI', 'CE',
#        'PE', 'AP', 'TO', 'SC', 'GO', 'MG', 'SP', 'SE', 'RJ', 'PB', 'AL',
#        'RN', 'ES', 'DF', 'RS', 'MS'], dtype=object)

# %%
len(dados["SG_UF_RESIDENCIA"].unique())
# Out:
# 27

# %%
dados["SG_UF_RESIDENCIA"].value_counts()
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
dados["NU_IDADE"].value_counts()
# Out:
# 18    21452
# 17    21256
# 19    14418
# 20    10413
# 16     7830
#       ...
# 75        2
# 73        2
# 82        1
# 77        1
# 76        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
dados["NU_IDADE"].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
dados["NU_IDADE"].hist()

# %%
dados["NU_IDADE"].hist(bins = 20, figsize = (10,8))

# %%
dados.query("IN_TREINEIRO == 1")["IN_TREINEIRO"]
# Out:
# 0         1
# 4         1
# 12        1
# 14        1
# 16        1
#          ..
# 127328    1
# 127340    1
# 127349    1
# 127350    1
# 127352    1
# Name: IN_TREINEIRO, Length: 15401, dtype: int64

# %%
dados.query("IN_TREINEIRO == 1")["NU_IDADE"].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %%
dados["NU_NOTA_REDACAO"].hist(bins = 20, figsize=(8, 6))

# %%
dados["NU_NOTA_LC"].hist(bins = 20, figsize=(8, 6))

# %% [markdown]
# Calculando a média das notas da redação

# %%
dados["NU_NOTA_REDACAO"].mean()
# Out:
# 571.5700253970197

# %% [markdown]
# Calculando o desvio padrão das notas da redação

# %%
dados["NU_NOTA_REDACAO"].std()
# Out:
# 188.07645455749753

# %%
provas = ["NU_NOTA_CN", "NU_NOTA_CH","NU_NOTA_MT", "NU_NOTA_LC", "NU_NOTA_REDACAO"]

dados[provas].describe()
# Out:
#          NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_MT    NU_NOTA_LC  NU_NOTA_REDACAO
# count  92758.000000  98043.000000  92758.000000  98043.000000     98043.000000
# mean     477.964015    507.365912    523.555206    520.463928       571.570025
# std       76.296099     82.972839    109.416939     64.556578       188.076455
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      418.000000    447.900000    435.300000    483.700000       480.000000
# 50%      470.200000    510.900000    501.600000    526.100000       580.000000
# 75%      533.300000    567.100000    598.200000    565.100000       680.000000
# max      797.300000    809.400000    985.000000    801.700000      1000.000000

# %%
#Obtendo o 25%, 50% e 75% com função
dados[provas].quantile([0.25,0.5,0.75])
# Out:
#       NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_MT  NU_NOTA_LC  NU_NOTA_REDACAO
# 0.25       418.0       447.9       435.3       483.7            480.0
# 0.50       470.2       510.9       501.6       526.1            580.0
# 0.75       533.3       567.1       598.2       565.1            680.0

# %%
dados["NU_NOTA_LC"].quantile(0.9)
# Out:
# 596.3

# %%
#Criando o primeiro boxplot
dados["NU_NOTA_LC"].plot.box(grid = True, figsize=(8,6))

# %%
dados[provas].plot.box(grid = True, figsize=(8,6))

# %%
#importando bibliotecas de visualização
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Fazendo um gráfico de dispersão de duas notas

plt.figure(figsize=(12,6))
ax = sns.scatterplot(x=dados.NU_NOTA_LC, y=dados.NU_NOTA_REDACAO, hue=dados.IN_TREINEIRO)
ax.set_title('Dispersão entre as notas de redação e Linguagem e Código com treineiros');

# %%
#CROSSTAB TREINEIRO/IDADE
pd.crosstab(index=dados['NU_IDADE'], columns=dados['IN_TREINEIRO'])
# Out:
# IN_TREINEIRO      0     1
# NU_IDADE
# 13                4     0
# 14               77    64
# 15               82  1927
# 16              688  7142
# 17            16355  4901
# ...             ...   ...
# 73                2     0
# 75                2     0
# 76                1     0
# 77                1     0
# 82                1     0
#
# [65 rows x 2 columns]

# %%
#idades dos treineiros
dados.query('IN_TREINEIRO == 1')['NU_IDADE'].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %%
#usando subset
treineiros = dados[dados['IN_TREINEIRO'] == 1]
candidatos = dados[dados['IN_TREINEIRO'] == 0]

# %%
#Criando dois histogramas juntos

plt.figure(figsize=(12,6))
sns.kdeplot(x=treineiros['NU_IDADE'], color='r');
sns.kdeplot(x=candidatos['NU_IDADE'], color='b');
plt.title('KdePlot de Idades por Treineiros e Não treineiros', fontsize=16);
plt.legend(labels=['Treineiros', 'Não Treineiros'])
plt.show()

# %% [markdown]
# Desafio01: Proporção de inscritos por idade.
#
# Desafio02: Descobrir de quais estados são os inscritos com 13 anos.
#
# Desafio03: Adicionar título no gráfico
#
# Desafio04: Plotar os Histrogramas das idades do treineiro e não treineiro
#
# Desafio05: Comparar as distribuições das provas em ingles espanhol
#
# Desafio06 : Explorar a documentação e visualizações

# %% [markdown]
# ##Desafio01: Proporção de inscritos por idade.

# %%
#Usando o parâmetro normalize

dados['NU_IDADE'].value_counts(normalize=True).sort_index()*100
# Out:
# 13     0.003140
# 14     0.110692
# 15     1.577171
# 16     6.146962
# 17    16.687078
#         ...
# 73     0.001570
# 75     0.001570
# 76     0.000785
# 77     0.000785
# 82     0.000785
# Name: NU_IDADE, Length: 65, dtype: float64

# %% [markdown]
# ##Desafio02: Descobrir de quais estados são os inscritos com 13 anos.

# %%
dados.query("NU_IDADE == 13")["SG_UF_RESIDENCIA"].value_counts().sort_index
# Out:
# <bound method Series.sort_index of MT    1
# BA    1
# AP    1
# SP    1
# Name: SG_UF_RESIDENCIA, dtype: int64>

# %%
#usando o loc
dados.loc[dados['NU_IDADE'] == 13]
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 57359   190003297248    2019                  3504107  ...    B     B    B
# 95630   190004825557    2019                  5107602  ...    A     A    B
# 98197   190004926952    2019                  1600303  ...    A     B    B
# 116501  190005659236    2019                  2917508  ...    B     C    B
#
# [4 rows x 136 columns]

# %%
#usando o slice
dados[dados.NU_IDADE == 13]
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 57359   190003297248    2019                  3504107  ...    B     B    B
# 95630   190004825557    2019                  5107602  ...    A     A    B
# 98197   190004926952    2019                  1600303  ...    A     B    B
# 116501  190005659236    2019                  2917508  ...    B     C    B
#
# [4 rows x 136 columns]

# %% [markdown]
# ##Desafio03: Adicionar título no gráfico

# %%
#gráfico com notas das 5 provas
dados[provas].boxplot(grid=True, figsize=(12,6)).set_title('BoxPlot Notas ENEM 2019', fontsize=20);

# %%
#Criando duas bases uma de treineiros e uma de candidatos
treineiros
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0       190001004661    2019                  1506138  ...    A     B    B
# 4       190001004776    2019                  1500800  ...    A     A    B
# 12      190001005076    2019                  1506138  ...    A     A    B
# 14      190001005081    2019                  1506807  ...    A     A    B
# 16      190001005202    2019                  1502301  ...    A     A    A
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127328  190006117441    2019                  3126752  ...    A     A    B
# 127340  190006117776    2019                  4305108  ...    A     C    B
# 127349  190006118483    2019                  2511301  ...    A     A    A
# 127350  190006118551    2019                  2611606  ...    B     B    B
# 127352  190006118561    2019                  2600807  ...    A     A    B
#
# [15401 rows x 136 columns]

# %%
candidatos
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 1       190001004674    2019                  1504208  ...    A     A    B
# 2       190001004722    2019                  1501402  ...    A     A    B
# 3       190001004735    2019                  1507300  ...    A     A    B
# 5       190001004841    2019                  1503606  ...    A     B    B
# 6       190001004856    2019                  1501402  ...    B     A    B
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127375  190006120035    2019                  3142700  ...    A     B    B
# 127376  190006120036    2019                  2902807  ...    A     B    B
# 127377  190006120037    2019                  2927408  ...    A     A    B
# 127378  190006120060    2019                  2930709  ...    A     A    A
# 127379  190006120170    2019                  3106200  ...    B     A    B
#
# [111979 rows x 136 columns]

# %%
#Histograma Idade Treineiros
plt.figure(figsize=(12,6))
ax = plt.hist(treineiros.NU_IDADE, bins=20)
plt.title('Histograma da idade dos treineiros');

# %%
#histograma Idade não treineiros
plt.figure(figsize=(12,6))
ax = plt.hist(candidatos.NU_IDADE, bins=20)
plt.title('Histograma da idade dos não treineiros');

# %%
#Desafio04

#Histograma Idade Treineiros

# %%
#Desafio 05

ax = sns.countplot(x=dados.TP_LINGUA)
ax.set_xticklabels(['Inglês', 'Espanhol']);

# %%
#distribuição das notas de Linguagem por língua estrangeira escolhida
plt.figure(figsize=(12,6))
ax = sns.boxplot(x=dados.TP_LINGUA, y= dados.NU_NOTA_LC)
ax.set_title('BoxPlot das notas de Linguagem e Código por Língua Estrangeira escolhida')
ax.set_xticklabels(['Inglês', 'Espanhol'])
ax.set_ylim(bottom=200)
plt.show()

# %% [markdown]
# ##Desafio06: Explorar a documentação e visualizações

# %%
#plotando a distribuição das notas de redação só com as pessoas que participaram de todas as provas
#lista com os tipos de presença
presenca = ['TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC', 'TP_PRESENCA_MT']

# %%
#dataset só com os presentes em aula
presentes = dados.query('TP_PRESENCA_CN == 1 & TP_PRESENCA_CN == 1 & TP_PRESENCA_LC == 1 & TP_PRESENCA_MT == 1')

# %%
presentes.shape
# Out:
# (92539, 136)

# %%
presentes['TP_PRESENCA_MT'].unique()
# Out:
# array([1])

# %%
#conferindo se há notas de redação nulas
presentes.NU_NOTA_REDACAO.isna().sum()
# Out:
# 0

# %%
#distribuição das notas de redação entre os presentes
plt.figure(figsize=(12,6))
ax = sns.kdeplot(presentes['NU_NOTA_REDACAO'], color='r')
ax.set_title('Distribuição das notas de Redação entre os candidatos presentes em todas as provas', fontsize=16);

# %% [markdown]
# ##**Aula** **02**

# %%
dados.query("NU_IDADE == 13")
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 57359   190003297248    2019                  3504107  ...    B     B    B
# 95630   190004825557    2019                  5107602  ...    A     A    B
# 98197   190004926952    2019                  1600303  ...    A     B    B
# 116501  190005659236    2019                  2917508  ...    B     C    B
#
# [4 rows x 136 columns]

# %%
#Em que estados moram os joovens que fizeram Enem 2019 com idade menor ou igual 14 anos
dados.query("NU_IDADE <= 14")["SG_UF_RESIDENCIA"].value_counts()
# Out:
# PE    18
# CE    15
# BA    14
# PA    12
# SP    11
# MG    11
# MA     9
# PI     7
# GO     7
# PB     7
# DF     4
# AM     4
# MT     4
# TO     3
# SE     3
# PR     3
# RO     2
# AL     2
# SC     2
# MS     1
# RS     1
# AC     1
# AP     1
# RJ     1
# ES     1
# RN     1
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
#Proporção por estados
dados.query("NU_IDADE <= 14")["SG_UF_RESIDENCIA"].value_counts(normalize=True)
# Out:
# PE    0.124138
# CE    0.103448
# BA    0.096552
# PA    0.082759
# SP    0.075862
# MG    0.075862
# MA    0.062069
# PI    0.048276
# GO    0.048276
# PB    0.048276
# DF    0.027586
# AM    0.027586
# MT    0.027586
# TO    0.020690
# SE    0.020690
# PR    0.020690
# RO    0.013793
# AL    0.013793
# SC    0.013793
# MS    0.006897
# RS    0.006897
# AC    0.006897
# AP    0.006897
# RJ    0.006897
# ES    0.006897
# RN    0.006897
# Name: SG_UF_RESIDENCIA, dtype: float64

# %%
#Plotando gráfico de pizza
alunos_menor_quartoze =  dados.query("NU_IDADE <= 14")
alunos_menor_quartoze["SG_UF_RESIDENCIA"].value_counts().plot.pie(figsize=(10,8))

# %%
#Plotando gráfico de barras
alunos_menor_quartoze["SG_UF_RESIDENCIA"].value_counts(normalize = True).plot.bar(figsize=(10,8))

# %%
len(alunos_menor_quartoze)
# Out:
# 145

# %%
# Visualizar a Q06 do questionário e as Notas de Matemátima 
plt.figure(figsize=(10,8))
sns.boxplot(x="Q006", y="NU_NOTA_MT", data = dados)
plt.title("Boxplot das notas de matématica pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matématica pela renda')

# %%
#Ordenando os dados gráfico

renda_ordena = dados["Q006"].unique()
renda_ordena.sort()
renda_ordena

plt.figure(figsize=(10,8))
sns.boxplot(x="Q006", y="NU_NOTA_MT", data = dados, order = renda_ordena)
plt.title("Boxplot das notas de matématica pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matématica pela renda')

# %%
#Obtendo a nota total através da soma
dados[provas].sum()
# Out:
# NU_NOTA_CN         44334986.1
# NU_NOTA_CH         49743676.1
# NU_NOTA_MT         48563933.8
# NU_NOTA_LC         51027844.9
# NU_NOTA_REDACAO    56038440.0
# dtype: float64

# %%
#Pegando a soma pelas linhas
dados[provas].sum(axis=1)
#Criar uma nova coluna e adicionando a soma
dados["NU_NOTA_TOTAL"] = dados[provas].sum(axis=1)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
#Criando um novo gráfico com os novos dados
plt.figure(figsize=(10,8))
sns.boxplot(x="Q006", y="NU_NOTA_TOTAL", data = dados, order = renda_ordena)
plt.title("Boxplot das notas de matématica pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matématica pela renda')

# %%
#Plotando Histograma com a Seaborn
sns.displot(dados, x ="NU_NOTA_TOTAL")

# %%
#Tentar entender o motivo das nota zero
provas = ["NU_NOTA_CN", "NU_NOTA_CH","NU_NOTA_MT", "NU_NOTA_LC", "NU_NOTA_REDACAO"]
provas.append("NU_NOTA_TOTAL")
dados.query("NU_NOTA_TOTAL == 0")
# Out:
#         NU_INSCRICAO  NU_ANO  ...  Q025 NU_NOTA_TOTAL
# 10      190001005028    2019  ...     A           0.0
# 11      190001005057    2019  ...     B           0.0
# 26      190001005484    2019  ...     B           0.0
# 38      190001006086    2019  ...     B           0.0
# 40      190001006292    2019  ...     B           0.0
# ...              ...     ...  ...   ...           ...
# 127351  190006118552    2019  ...     B           0.0
# 127365  190006119756    2019  ...     A           0.0
# 127366  190006119783    2019  ...     A           0.0
# 127368  190006119802    2019  ...     B           0.0
# 127374  190006119995    2019  ...     B           0.0
#
# [29162 rows x 137 columns]

# %%
#Separar dados sem notas zero
dados_sem_notas_zero = dados.query("NU_NOTA_TOTAL !=0")
dados_sem_notas_zero.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
#Criando um novo gráfico com os novos dados
plt.figure(figsize=(10,8))
sns.boxplot(x="Q006", y="NU_NOTA_TOTAL", data = dados_sem_notas_zero, order = renda_ordena)
plt.title("Boxplot das notas de matématica pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matématica pela renda')

# %%
#Criando um novo gráfico com os novos dados com um novo parâmetro
plt.figure(figsize=(14,8))
sns.boxplot(x="Q006", y="NU_NOTA_TOTAL", data = dados_sem_notas_zero, 
            hue = "IN_TREINEIRO", order = renda_ordena)
plt.title("Boxplot das notas de matématica pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matématica pela renda')

# %% [markdown]
# MEGA DESAFIO DA THAÍNA: Pegar a amostra completa dos alunos de 13 e 14 anos
#
# Desafio do Gui bonzinho: aumentar a amostra para alunos menor de idade e comparar por estado
#
# Desafio03: Criar uma função para plotar o boxplot do seaborn
#
# Desafio04: Verificar se quem zerou a prova foi eliminado ou não estava presente
#
# Desafio05: Quem é eliminado tira zero ou será NaN( Não teve registro de notas)
#
# Desafio06: Verificar a proporção dos partcicpantes de renadas mais altas e mais baixas como treineiro e não treineiros.
#
# Desafio07: Fazer o mesmo boxplot olhando para a questão 25 (tem i nternet ou não) e fazer uma reflexão sobre o assunto e o contexto de pandemia.
#
# Desafio08: Verificação por quem tem carro ou não

# %% [markdown]
# ##Desafio do Gui bonzinho: aumentar a amostra para alunos menor de idade e comparar por estado

# %% [markdown]
# ##Desafio04: Verificar se quem zerou a prova foi eliminado ou não estava presente

# %%
#Obtendo as notas )
total_zerado = dados.query('NU_NOTA_TOTAL == 0')
total_zerado
# Out:
#         NU_INSCRICAO  NU_ANO  ...  Q025 NU_NOTA_TOTAL
# 10      190001005028    2019  ...     A           0.0
# 11      190001005057    2019  ...     B           0.0
# 26      190001005484    2019  ...     B           0.0
# 38      190001006086    2019  ...     B           0.0
# 40      190001006292    2019  ...     B           0.0
# ...              ...     ...  ...   ...           ...
# 127351  190006118552    2019  ...     B           0.0
# 127365  190006119756    2019  ...     A           0.0
# 127366  190006119783    2019  ...     A           0.0
# 127368  190006119802    2019  ...     B           0.0
# 127374  190006119995    2019  ...     B           0.0
#
# [29162 rows x 137 columns]

# %%
#Verificar os tipos de presença neste novo dataset
#Criar uma lista para os tipos de presença
presenca =  ['TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC', 'TP_PRESENCA_MT']

for prova in presenca:
  print(f'Presenca: {prova}, valores: {total_zerado[prova].unique()}')
# Out:
# Presenca: TP_PRESENCA_CN, valores: [0 1]
# Presenca: TP_PRESENCA_CH, valores: [0 2 1]
# Presenca: TP_PRESENCA_LC, valores: [0 2 1]
# Presenca: TP_PRESENCA_MT, valores: [0 1]

# %%
#localizan#localizando a coluna de nota de lingaugem entre os eliminados na prova de linguagem 
dados.query('TP_PRESENCA_LC  == 2')['NU_NOTA_LC'].unique() do a coluna de nota de lingaugem entre os eliminados na prova de linguagem 
dados.query('TP_PRESENCA_LC  == 2')['NU_NOTA_LC'].unique()
# Out:
#   File "<ipython-input-67-c4a731bdd787>", line 2
#     dados.query('TP_PRESENCA_LC  == 2')['NU_NOTA_LC'].unique() do a coluna de nota de lingaugem entre os eliminados na prova de linguagem
#                                                                 ^
# SyntaxError: invalid syntax

# %%
#localizando a coluna de nota de lingaugem entre os eliminados na prova de ciência humana
dados.query('TP_PRESENCA_LC  == 2')['NU_NOTA_CH'].unique()

# %% [markdown]
# MEGA DESAFIO DA THAÍNA: Pegar a amostra completa dos alunos de 13 e 14 anos
#
# Desafio do Gui bonzinho: aumentar a amostra para alunos menor de idade e comparar por estado
#
# Desafio03: Criar uma função para plotar o boxplot do seaborn
#
# Desafio04: Verificar se quem zerou a prova foi eliminado ou não estava presente
#
# Desafio05: Quem é eliminado tira zero ou será NaN( Não teve registro de notas)
#
# Desafio06: Verificar a proporção dos partcicpantes de renadas mais altas e mais baixas como treineiro e não treineiros.
#
# Desafio07: Fazer o mesmo boxplot olhando para a questão 25 (tem i nternet ou não) e fazer uma reflexão sobre o assunto e o contexto de pandemia.
#
# Desafio08: Verificação por quem tem carro ou não

# %% [markdown]
# ##Desafio06: Verificar a proporção dos partcicpantes de renadas mais altas e mais baixas como treineiro e não treineiros.

# %%
#Usando o crosstab
cross = pd.DataFrame(data=pd.crostab(index=dados.Q006, columns=dados.IN_TREINEIRO))
cross

# %% [markdown]
# ##Desafio07: Fazer o mesmo boxplot olhando para a questão 25 (tem i nternet ou não) e fazer uma reflexão sobre o assunto e o contexto de pandemia.

# %%
plt.figure(figsize=(15,8))
plt.title('Boxplot das somas das notas por acesso à internet', fontsize=20)
ax = sns.boxplot(x='Q025', y='NU_NOTA_TOTAL', order=dados.Q025.unique(), 
                 data=dados_sem_nota_zero)
ax.set_xticklabels(['Sim', 'Não'])
ax.set_xlabel('Acesso à internet')
plt.show()

# %% [markdown]
# **##Aula 03**

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x="NU_NOTA_TOTAL")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x="NU_NOTA_MT")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x="NU_NOTA_LC")

# %% [markdown]
# Desafio01: Plotar as  médias, medianas e modas nas notas de LC e MT (matplotlib linha vertical)

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x="NU_NOTA_TOTAL", hue="Q025", kde=True, stat="probability", cumulative=True) #density)

# %%
#Analisando a relação de uma nota com outra
plt.figure(figsize=(10,8))
sns.scatterplot(data=dados_sem_notas_zero, x="NU_NOTA_MT", y="NU_NOTA_LC")
plt.xlim((50,1050))
plt.ylim((50,1050))
# Out:
# (50.0, 1050.0)

# %%
provas
# Out:
# ['NU_NOTA_CN',
#  'NU_NOTA_CH',
#  'NU_NOTA_MT',
#  'NU_NOTA_LC',
#  'NU_NOTA_REDACAO',
#  'NU_NOTA_TOTAL']

# %%
#Plotando matrizes de gráficos das notas 
sns.pairplot(dados_sem_notas_zero[provas])
